# %%
# %matplotlib inline
#Dependencies 
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
file = "Resources/car_insurance_claim.csv"
claim_data = pd.read_csv(file)
claim_data
# Out:
#               ID  KIDSDRIV    BIRTH   AGE  HOMEKIDS   YOJ    INCOME PARENT1  \
# 0       63581743         0  16MAR39  60.0         0  11.0   $67,349      No
# 1      132761049         0  21JAN56  43.0         0  11.0   $91,449      No
# 2      921317019         0  18NOV51  48.0         0  11.0   $52,881      No
# 3      727598473         0  05MAR64  35.0         1  10.0   $16,039      No
# 4      450221861         0  05JUN48  51.0         0  14.0       NaN      No
# 5      743146596         0  17MAY49  50.0         0   NaN  $114,986      No
# 6      871024631         0  05MAY65  34.0         1  12.0  $125,301     Yes
# 7      792300541         0  28FEB45  54.0         0   NaN   $18,755      No
# 8        7945239         1  17SEP59  40.0         1  11.0   $50,815     Yes
# 9        3577610         0  21AUG55  44.0         2  12.0   $43,486     Yes
# 10     892208080         1  14DEC61  37.0         2   NaN  $107,961      No
# ...

# %%
claim_data.dtypes
# Out:
# ID              int64
# KIDSDRIV        int64
# BIRTH          object
# AGE           float64
# HOMEKIDS        int64
# YOJ           float64
# INCOME         object
# PARENT1        object
# HOME_VAL       object
# MSTATUS        object
# GENDER         object
# EDUCATION      object
# OCCUPATION     object
# TRAVTIME        int64
# CAR_USE        object
# BLUEBOOK       object
# TIF             int64
# CAR_TYPE       object
# RED_CAR        object
# OLDCLAIM       object
# CLM_FREQ        int64
# REVOKED        object
# MVR_PTS         int64
# CLM_AMT        object
# CAR_AGE       float64
# CLAIM_FLAG      int64
# URBANICITY     object
# dtype: object

# %%
#del claim_data[]

# %%
claim_data.count()
# Out:
# ID            10302
# KIDSDRIV      10302
# BIRTH         10302
# AGE           10295
# HOMEKIDS      10302
# YOJ            9754
# INCOME         9732
# PARENT1       10302
# HOME_VAL       9727
# MSTATUS       10302
# GENDER        10302
# EDUCATION     10302
# OCCUPATION     9637
# TRAVTIME      10302
# CAR_USE       10302
# BLUEBOOK      10302
# TIF           10302
# CAR_TYPE      10302
# RED_CAR       10302
# OLDCLAIM      10302
# CLM_FREQ      10302
# REVOKED       10302
# MVR_PTS       10302
# CLM_AMT       10302
# CAR_AGE        9663
# CLAIM_FLAG    10302
# URBANICITY    10302
# dtype: int64

# %%
#drop rows with missing information 
claim_data = claim_data.dropna(how='any')

# %%
claim_data.count()
# Out:
# ID            7657
# KIDSDRIV      7657
# BIRTH         7657
# AGE           7657
# HOMEKIDS      7657
# YOJ           7657
# INCOME        7657
# PARENT1       7657
# HOME_VAL      7657
# MSTATUS       7657
# GENDER        7657
# EDUCATION     7657
# OCCUPATION    7657
# TRAVTIME      7657
# CAR_USE       7657
# BLUEBOOK      7657
# TIF           7657
# CAR_TYPE      7657
# RED_CAR       7657
# OLDCLAIM      7657
# CLM_FREQ      7657
# REVOKED       7657
# MVR_PTS       7657
# CLM_AMT       7657
# CAR_AGE       7657
# CLAIM_FLAG    7657
# URBANICITY    7657
# dtype: int64

# %%
#disply an overview of a column
claim_data["MSTATUS"].value_counts()
# Out:
# Yes     4579
# z_No    3078
# Name: MSTATUS, dtype: int64

# %%
# yes with married & z_No with single 
claim_data['MSTATUS'] = claim_data['MSTATUS'].replace({'Yes':'married', 'z_No':'single'})

# %%
claim_data['MSTATUS'].value_counts()
# Out:
# married    4579
# single     3078
# Name: MSTATUS, dtype: int64

# %%
#disply a statistical over view
claim_data.describe(include='all')
# Out:
#                   ID     KIDSDRIV    BIRTH          AGE     HOMEKIDS  \
# count   7.657000e+03  7657.000000     7657  7657.000000  7657.000000
# unique           NaN          NaN     5422          NaN          NaN
# top              NaN          NaN  10OCT53          NaN          NaN
# freq             NaN          NaN        6          NaN          NaN
# mean    4.980240e+08     0.172130      NaN    44.700535     0.740629
# std     2.852377e+08     0.511254      NaN     8.675642     1.129129
# min     4.012760e+05     0.000000      NaN    16.000000     0.000000
# 25%     2.517504e+08     0.000000      NaN    39.000000     0.000000
# 50%     4.989367e+08     0.000000      NaN    45.000000     0.000000
# 75%     7.406986e+08     0.000000      NaN    51.000000     1.000000
# max     9.999264e+08     4.000000      NaN    81.000000     5.000000
#
#                 YOJ INCOME PARENT1 HOME_VAL  MSTATUS         ...           \
# ...

# %%
# Create a new DataFrame that looks into a category 
#e.g
single = claim_data['MSTATUS']=='single'
claim_single = claim_data.loc[single]
claim_single.head()
# Out:
#           ID  KIDSDRIV    BIRTH   AGE  HOMEKIDS   YOJ    INCOME PARENT1  \
# 0   63581743         0  16MAR39  60.0         0  11.0   $67,349      No
# 1  132761049         0  21JAN56  43.0         0  11.0   $91,449      No
# 2  921317019         0  18NOV51  48.0         0  11.0   $52,881      No
# 6  871024631         0  05MAY65  34.0         1  12.0  $125,301     Yes
# 8    7945239         1  17SEP59  40.0         1  11.0   $50,815     Yes
#
#    HOME_VAL MSTATUS         ...             CAR_TYPE RED_CAR OLDCLAIM  \
# 0        $0  single         ...              Minivan     yes   $4,461
# 1  $257,252  single         ...              Minivan     yes       $0
# 2        $0  single         ...                  Van     yes       $0
# 6        $0  single         ...           Sports Car      no       $0
# 8        $0  single         ...              Minivan      no   $3,295
#
#    CLM_FREQ REVOKED MVR_PTS  CLM_AMT CAR_AGE CLAIM_FLAG           URBANICITY
# ...

# %%
claim_single = claim_data.loc[claim_data['MSTATUS']=='single',['INCOME','MSTATUS']]
claim_single.head()
# Out:
#      INCOME MSTATUS
# 0   $67,349  single
# 1   $91,449  single
# 2   $52,881  single
# 6  $125,301  single
# 8   $50,815  single

# %%
# circle graph of which driver vehicles are involved the most with filing insurance claim 

# red car drivers with claim frequency dataframe

claim_data["INCOME"].head()
# Out:
# 0    $67,349
# 1    $91,449
# 2    $52,881
# 3    $16,039
# 4        NaN
# Name: INCOME, dtype: object

# %%
#scatter plot (does not work)

#x_limit1 = claim_data.loc[claim_data["URBANICITY"] == "Highly Urban/ Urban"].groupby("ID")["AGE"].sum()
#bubbles1 = claim_data.loc[claim_data["URBANICITY"] == "Highly Urban/ Urban"].groupby("ID")["CLM_FREQ"].sum()

#x_limit2 = claim_data.loc[claim_data["URBANICITY"] == "z_Highly Rural/ Rural"].groupby("ID")["AGE"].sum()
#bubbles2 = claim_data.loc[claim_data["URBANICITY"] == "z_Highly Rural/ Rural"].groupby("ID")["CLM_FREQ"].sum()

#data1 = claim_data.loc[claim_data["URBANICITY"] == "Highly Urban/ Urban"].groupby("ID")["CLM_AMT"].sum()
#data2 = claim_data.loc[claim_data["URBANICITY"] == "z_Highly Rural/ Rural"].groupby("ID")["CLM_AMT"].sum()



#plt.scatter(x_limit1, data1, marker="o", facecolors="lightcoral", label=Urban, edgecolor="black", 
            #s=bubbles1)
#plt.scatter(x_limit2, data2, marker="o", facecolors="lightskyblue", label= Rural, edgecolor="black", 
            #s=bubbles2)
#plt.grid()


#plt.title("Red Car Drivers Data")
#plt.xlabel("Age")
#plt.ylabel("Claim Amount")


#legnd = plt.legend(title="City Types", loc="upper right", scatterpoints=1, fontsize=10)
#for handle in legnd.legendHandles:
    #handle.set_sizes([20.0])


#plt.text(1, 1, "Note: The circle size correlates with the claim frequency of the driver")

#plt.savefig("PNG Images/red_cars.png")

#plt.show()

# %%
# Graph of each car type portion in the data
#city = claim_data.groupby("CAR_TYPE")["CAR_TYPE"].unique()
#city

#fare_list = claim_data.groupby("CAR_TYPE")["ID"].count()
#colors = ["gold", "lightskyblue", "lightcoral", "green", "orange", "pink"]

#explode = (0, 0, 0, 0, 0, 0)
#plt.pie(fare_list, labels=city, explode=explode, colors=colors, autopct="%1.1f%%", shadow=True, startangle=160)

#plt.title("% of Total Fares by ")
#plt.axis("equal")
plt.tight_layout()
plt.savefig("PNG Images/graph.png")         
plt.show()
